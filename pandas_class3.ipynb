# %%
import pandas as pd

# %%
data = {
    'Name':['Vivek','Abc','Xyz','Lmn'],
    'Salary':[100,200,300,400],
    'mail id':['Vivek@codifyd.com','Abc@codifyd.com','Xyz@codifyd.com','Lmn@codifyd.com'],
    'Address':['Dnr','Ptn','Kkr','Hjp']
}

# %%
df = pd.DataFrame(data)

# %%
df
# Out:
#     Name  Salary            mail id Address
# 0  Vivek     100  Vivek@codifyd.com     Dnr
# 1    Abc     200    Abc@codifyd.com     Ptn
# 2    Xyz     300    Xyz@codifyd.com     Kkr
# 3    Lmn     400    Lmn@codifyd.com     Hjp

# %%
df.iloc[1:3,0:len(df.columns)]
# Out:
#   Name  Salary          mail id Address
# 1  Abc     200  Abc@codifyd.com     Ptn
# 2  Xyz     300  Xyz@codifyd.com     Kkr

# %%
# loc checks the named index
# iloc checks the default index

# %%
data2 = {
    'pf_no':['234','45','54465','656'],
    'inc_tax':['234','565','767','6776'],
    'mob_no':['23543','43543','454','5656'],
    'courses':['ds','bigdata','web-dev','blockchain']
}

# %%
df2 = pd.DataFrame(data2)

# %%
# axis=1 tells to concat based on columns
# axis=0 tells to concat based on rows
pd.concat([df,df2],axis = 1)
# Out:
#     Name  Salary            mail id Address  pf_no inc_tax mob_no     courses
# 0  Vivek     100  Vivek@codifyd.com     Dnr    234     234  23543          ds
# 1    Abc     200    Abc@codifyd.com     Ptn     45     565  43543     bigdata
# 2    Xyz     300    Xyz@codifyd.com     Kkr  54465     767    454     web-dev
# 3    Lmn     400    Lmn@codifyd.com     Hjp    656    6776   5656  blockchain

# %% [markdown]
# # Merge operation
# merge in pandas is equivalent to join in sql

# %%
data3 = {
    'empid':[101,102,103,104],
    'salary':[234,345,200,400],
    'pf':[23,34,56,78]
}

# %%
data4 = {
    'empid':[101,102,104,105],
    'mobno':[3434,5656,767,878],
    'houseno':[345,345,345,56]
}

# %%
df3 = pd.DataFrame(data3)

# %%
df4 = pd.DataFrame(data4)

# %%
pd.merge(df3,df4)
# Out:
#    empid  salary  pf  mobno  houseno
# 0    101     234  23   3434      345
# 1    102     345  34   5656      345
# 2    104     400  78    767      345

# %%
# merge(left df|series,right df|series) -> Merge DataFrame or named Series objects with a database-style join.
# how : {'left', 'right', 'outer', 'inner', 'cross'}, default 'inner'

# %%
df3
# Out:
#    empid  salary  pf
# 0    101     234  23
# 1    102     345  34
# 2    103     200  56
# 3    104     400  78

# %%
df4
# Out:
#    empid  mobno  houseno
# 0    101   3434      345
# 1    102   5656      345
# 2    104    767      345
# 3    105    878       56

# %%
# by default, merge operation performs inner join. It looks for a column which is common in both the dataframe then merges
# all the rows which is present in both the dataframe 
innerjoin_df = pd.merge(df3,df4)

# %%
innerjoin_df
# Out:
#    empid  salary  pf  mobno  houseno
# 0    101     234  23   3434      345
# 1    102     345  34   5656      345
# 2    104     400  78    767      345

# %%
# we can give on which column to join by ourself using 'on' attribute
pd.merge(df3,df4,on='empid')
# Out:
#    empid  salary  pf  mobno  houseno
# 0    101     234  23   3434      345
# 1    102     345  34   5656      345
# 2    104     400  78    767      345

# %%
# use only keys from left frame, similar to a SQL left outer join;
# preserve key order
leftjoin_df = pd.merge(df3,df4,how='left')

# %%
df3
# Out:
#    empid  salary  pf
# 0    101     234  23
# 1    102     345  34
# 2    103     200  56
# 3    104     400  78

# %%
df4
# Out:
#    empid  mobno  houseno
# 0    101   3434      345
# 1    102   5656      345
# 2    104    767      345
# 3    105    878       56

# %%
leftjoin_df
# Out:
#    empid  salary  pf   mobno  houseno
# 0    101     234  23  3434.0    345.0
# 1    102     345  34  5656.0    345.0
# 2    103     200  56     NaN      NaN
# 3    104     400  78   767.0    345.0

# %%
rightjoin_df = pd.merge(df3,df4,how='right')

# %%
df3
# Out:
#    empid  salary  pf
# 0    101     234  23
# 1    102     345  34
# 2    103     200  56
# 3    104     400  78

# %%
df4
# Out:
#    empid  mobno  houseno
# 0    101   3434      345
# 1    102   5656      345
# 2    104    767      345
# 3    105    878       56

# %%
rightjoin_df
# Out:
#    empid  salary    pf  mobno  houseno
# 0    101   234.0  23.0   3434      345
# 1    102   345.0  34.0   5656      345
# 2    104   400.0  78.0    767      345
# 3    105     NaN   NaN    878       56

# %%
data5 = {
    'empid1':[101,102,103,104],
    'salary':[234,345,200,400],
    'pf':[23,34,56,78]
}
data6 = {
    'empid2':[101,102,104,105],
    'mobno':[3434,5656,767,878],
    'houseno':[345,345,345,56]
}

# %%
# In the above case, we dont have two columns with same name in out dataframes.
# In that case we can use 'left_on' and 'right_on' attributes

# %%
df5 = pd.DataFrame(data5)
df6 = pd.DataFrame(data6)

# %%
df5
# Out:
#    empid1  salary  pf
# 0     101     234  23
# 1     102     345  34
# 2     103     200  56
# 3     104     400  78

# %%
df6
# Out:
#    empid2  mobno  houseno
# 0     101   3434      345
# 1     102   5656      345
# 2     104    767      345
# 3     105    878       56

# %%
pd.merge(df5,df6,left_on='empid1',right_on='empid2')
# Out:
#    empid1  salary  pf  empid2  mobno  houseno
# 0     101     234  23     101   3434      345
# 1     102     345  34     102   5656      345
# 2     104     400  78     104    767      345

# %%
# We can perform the merge operation based on multiple columns

# %%
data7 = {
    'empid':[101,102,103,104],
    'salary':[234,345,200,400],
    'pf':[23,34,56,78]
}
data8 = {
    'empid':[101,102,104,105],
    'salary':[234,345,200,878],
    'houseno':[345,345,345,56]
}

# %%
df7 = pd.DataFrame(data7)
df8 = pd.DataFrame(data8)

# %%
pd.merge(df7,df8,on=['empid','salary'])
# Out:
#    empid  salary  pf  houseno
# 0    101     234  23      345
# 1    102     345  34      345

# %%
# 'merge' joins two df based on columns
# we can use 'join' to join two columns based on row index

# %%
data9 = {
    'empid1':[101,102,103,104],
    'salary1':[234,345,200,400],
    'pf':[23,34,56,78]
}
data10 = {
    'empid2':[101,102,104,105,123],
    'salary2':[234,345,200,878,43],
    'houseno':[345,345,345,56,234]
}

# %%
df9 = pd.DataFrame(data9,index=['a','b','c','d'])
df10 = pd.DataFrame(data10,index=['a','b','d','e','f'])

# %%
df9
# Out:
#    empid1  salary1  pf
# a     101      234  23
# b     102      345  34
# c     103      200  56
# d     104      400  78

# %%
df10
# Out:
#    empid2  salary2  houseno
# a     101      234      345
# b     102      345      345
# d     104      200      345
# e     105      878       56
# f     123       43      234

# %%
df9.join(df10)
# Out:
#    empid1  salary1  pf  empid2  salary2  houseno
# a     101      234  23   101.0    234.0    345.0
# b     102      345  34   102.0    345.0    345.0
# c     103      200  56     NaN      NaN      NaN
# d     104      400  78   104.0    200.0    345.0

# %%
# We can specify how in join method as well, here the default value is left

# %%
sales_df = pd.read_csv("C:\\MyData\\MyData\\data science\\resources\\data sets\\sales_data_final.csv")

# %%
sales_df.head()
# Out:
#           order_id order_date ship_date       ship_mode    customer_name  \
# 0     AG-2011-2040   1/1/2011  1/6/2011  Standard Class  Toby Braunhardt
# 1    IN-2011-47883   1/1/2011  1/8/2011  Standard Class      Joseph Holt
# 2     HU-2011-1220   1/1/2011  1/5/2011    Second Class    Annie Thurman
# 3  IT-2011-3647632   1/1/2011  1/5/2011    Second Class     Eugene Moren
# 4    IN-2011-47883   1/1/2011  1/8/2011  Standard Class      Joseph Holt
#
#        segment            state    country  market   region  ...  \
# 0     Consumer      Constantine    Algeria  Africa   Africa  ...
# 1     Consumer  New South Wales  Australia    APAC  Oceania  ...
# 2     Consumer         Budapest    Hungary    EMEA     EMEA  ...
# 3  Home Office        Stockholm     Sweden      EU    North  ...
# 4     Consumer  New South Wales  Australia    APAC  Oceania  ...
#
#           category sub_category                 product_name sales quantity  \
# 0  Office Supplies      Storage          Tenex Lockers, Blue   408        2
# 1  Office Supplies     Supplies     Acme Trimmer, High Speed   120        3
# 2  Office Supplies      Storage      Tenex Box, Single Width    66        4
# 3  Office Supplies        Paper  Enermax Note Cards, Premium    45        3
# 4        Furniture  Furnishings   Eldon Light Bulb, Duo Pack   114        5
#
#    discount   profit  shipping_cost  order_priority  year
# 0       0.0  106.140          35.46          Medium  2011
# 1       0.1   36.036           9.72          Medium  2011
# 2       0.0   29.640           8.17            High  2011
# 3       0.5  -26.055           4.82            High  2011
# 4       0.1   37.770           4.70          Medium  2011
#
# [5 rows x 21 columns]

# %%
sales_df[sales_df['profit']<0]['profit_flag'] = "Negative"
# Out:
# C:\Users\kumar\AppData\Local\Temp\ipykernel_16212\1038870405.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   sales_df[sales_df['profit']<0]['profit_flag'] = "Negative"

# %%
sales_df
# Out:
#               order_id  order_date ship_date       ship_mode  \
# 0         AG-2011-2040    1/1/2011  1/6/2011  Standard Class
# 1        IN-2011-47883    1/1/2011  1/8/2011  Standard Class
# 2         HU-2011-1220    1/1/2011  1/5/2011    Second Class
# 3      IT-2011-3647632    1/1/2011  1/5/2011    Second Class
# 4        IN-2011-47883    1/1/2011  1/8/2011  Standard Class
# ...                ...         ...       ...             ...
# 51285   CA-2014-115427  12/31/2014  1/4/2015  Standard Class
# 51286     MO-2014-2560  12/31/2014  1/5/2015  Standard Class
# 51287   MX-2014-110527  12/31/2014  1/2/2015    Second Class
# 51288   MX-2014-114783  12/31/2014  1/6/2015  Standard Class
# 51289   CA-2014-156720  12/31/2014  1/4/2015  Standard Class
#
#           customer_name      segment             state        country  market  \
# 0       Toby Braunhardt     Consumer       Constantine        Algeria  Africa
# 1           Joseph Holt     Consumer   New South Wales      Australia    APAC
# 2         Annie Thurman     Consumer          Budapest        Hungary    EMEA
# 3          Eugene Moren  Home Office         Stockholm         Sweden      EU
# 4           Joseph Holt     Consumer   New South Wales      Australia    APAC
# ...                 ...          ...               ...            ...     ...
# 51285        Erica Bern    Corporate        California  United States      US
# 51286         Liz Preis     Consumer  Souss-Massa-Dra        Morocco  Africa
# 51287  Charlotte Melton     Consumer           Managua      Nicaragua   LATAM
# 51288     Tamara Dahlen     Consumer         Chihuahua         Mexico   LATAM
# 51289     Jill Matthias     Consumer          Colorado  United States      US
#
#         region  ...         category sub_category  \
# 0       Africa  ...  Office Supplies      Storage
# 1      Oceania  ...  Office Supplies     Supplies
# 2         EMEA  ...  Office Supplies      Storage
# 3        North  ...  Office Supplies        Paper
# 4      Oceania  ...        Furniture  Furnishings
# ...        ...  ...              ...          ...
# 51285     West  ...  Office Supplies      Binders
# 51286   Africa  ...  Office Supplies      Binders
# 51287  Central  ...  Office Supplies       Labels
# 51288    North  ...  Office Supplies       Labels
# 51289     West  ...  Office Supplies    Fasteners
#
#                                           product_name sales quantity  \
# 0                                  Tenex Lockers, Blue   408        2
# 1                             Acme Trimmer, High Speed   120        3
# 2                              Tenex Box, Single Width    66        4
# 3                          Enermax Note Cards, Premium    45        3
# 4                           Eldon Light Bulb, Duo Pack   114        5
# ...                                                ...   ...      ...
# 51285  Cardinal Slant-D Ring Binder, Heavy Gauge Vinyl    14        2
# 51286          Wilson Jones Hole Reinforcements, Clear     4        1
# 51287           Hon Color Coded Labels, 5000 Label Set    26        3
# 51288           Hon Legal Exhibit Labels, Alphabetical     7        1
# 51289                              Bagged Rubber Bands     3        3
#
#        discount    profit  shipping_cost  order_priority  year
# 0           0.0  106.1400          35.46          Medium  2011
# 1           0.1   36.0360           9.72          Medium  2011
# 2           0.0   29.6400           8.17            High  2011
# 3           0.5  -26.0550           4.82            High  2011
# 4           0.1   37.7700           4.70          Medium  2011
# ...         ...       ...            ...             ...   ...
# 51285       0.2    4.5188           0.89          Medium  2014
# 51286       0.0    0.4200           0.49          Medium  2014
# 51287       0.0   12.3600           0.35          Medium  2014
# 51288       0.0    0.5600           0.20          Medium  2014
# 51289       0.2   -0.6048           0.17          Medium  2014
#
# [51290 rows x 21 columns]

# %% [markdown]
# # We have to create a column profit_flag which will store positive or negative based on the profit

# %%
def profit_flag(profit):
    if profit<0:
        return "negative"
    else:
        return "positive"

# %%
# apply() method-> Apply a function along an axis of the DataFrame. Takes a function as arguement
sales_df['profit_flag'] = sales_df['profit'].apply(profit_flag)

# %%
sales_df
# Out:
#               order_id  order_date ship_date       ship_mode  \
# 0         AG-2011-2040    1/1/2011  1/6/2011  Standard Class
# 1        IN-2011-47883    1/1/2011  1/8/2011  Standard Class
# 2         HU-2011-1220    1/1/2011  1/5/2011    Second Class
# 3      IT-2011-3647632    1/1/2011  1/5/2011    Second Class
# 4        IN-2011-47883    1/1/2011  1/8/2011  Standard Class
# ...                ...         ...       ...             ...
# 51285   CA-2014-115427  12/31/2014  1/4/2015  Standard Class
# 51286     MO-2014-2560  12/31/2014  1/5/2015  Standard Class
# 51287   MX-2014-110527  12/31/2014  1/2/2015    Second Class
# 51288   MX-2014-114783  12/31/2014  1/6/2015  Standard Class
# 51289   CA-2014-156720  12/31/2014  1/4/2015  Standard Class
#
#           customer_name      segment             state        country  market  \
# 0       Toby Braunhardt     Consumer       Constantine        Algeria  Africa
# 1           Joseph Holt     Consumer   New South Wales      Australia    APAC
# 2         Annie Thurman     Consumer          Budapest        Hungary    EMEA
# 3          Eugene Moren  Home Office         Stockholm         Sweden      EU
# 4           Joseph Holt     Consumer   New South Wales      Australia    APAC
# ...                 ...          ...               ...            ...     ...
# 51285        Erica Bern    Corporate        California  United States      US
# 51286         Liz Preis     Consumer  Souss-Massa-Dra        Morocco  Africa
# 51287  Charlotte Melton     Consumer           Managua      Nicaragua   LATAM
# 51288     Tamara Dahlen     Consumer         Chihuahua         Mexico   LATAM
# 51289     Jill Matthias     Consumer          Colorado  United States      US
#
#         region  ... sub_category  \
# 0       Africa  ...      Storage
# 1      Oceania  ...     Supplies
# 2         EMEA  ...      Storage
# 3        North  ...        Paper
# 4      Oceania  ...  Furnishings
# ...        ...  ...          ...
# 51285     West  ...      Binders
# 51286   Africa  ...      Binders
# 51287  Central  ...       Labels
# 51288    North  ...       Labels
# 51289     West  ...    Fasteners
#
#                                           product_name sales quantity  \
# 0                                  Tenex Lockers, Blue   408        2
# 1                             Acme Trimmer, High Speed   120        3
# 2                              Tenex Box, Single Width    66        4
# 3                          Enermax Note Cards, Premium    45        3
# 4                           Eldon Light Bulb, Duo Pack   114        5
# ...                                                ...   ...      ...
# 51285  Cardinal Slant-D Ring Binder, Heavy Gauge Vinyl    14        2
# 51286          Wilson Jones Hole Reinforcements, Clear     4        1
# 51287           Hon Color Coded Labels, 5000 Label Set    26        3
# 51288           Hon Legal Exhibit Labels, Alphabetical     7        1
# 51289                              Bagged Rubber Bands     3        3
#
#       discount    profit  shipping_cost  order_priority  year profit_flag
# 0          0.0  106.1400          35.46          Medium  2011    positive
# 1          0.1   36.0360           9.72          Medium  2011    positive
# 2          0.0   29.6400           8.17            High  2011    positive
# 3          0.5  -26.0550           4.82            High  2011    negative
# 4          0.1   37.7700           4.70          Medium  2011    positive
# ...        ...       ...            ...             ...   ...         ...
# 51285      0.2    4.5188           0.89          Medium  2014    positive
# 51286      0.0    0.4200           0.49          Medium  2014    positive
# 51287      0.0   12.3600           0.35          Medium  2014    positive
# 51288      0.0    0.5600           0.20          Medium  2014    positive
# 51289      0.2   -0.6048           0.17          Medium  2014    negative
#
# [51290 rows x 22 columns]

# %% [markdown]
# # We have to create a column customer name length to store length of customer name

# %%
def name_len(name):
    return len(name)

# %%
sales_df['customer_name_len'] = sales_df['customer_name'].apply(name_len)
# sales_df['customer_name'].apply(len) will also work

# %%
sales_df
# Out:
#               order_id  order_date ship_date       ship_mode  \
# 0         AG-2011-2040    1/1/2011  1/6/2011  Standard Class
# 1        IN-2011-47883    1/1/2011  1/8/2011  Standard Class
# 2         HU-2011-1220    1/1/2011  1/5/2011    Second Class
# 3      IT-2011-3647632    1/1/2011  1/5/2011    Second Class
# 4        IN-2011-47883    1/1/2011  1/8/2011  Standard Class
# ...                ...         ...       ...             ...
# 51285   CA-2014-115427  12/31/2014  1/4/2015  Standard Class
# 51286     MO-2014-2560  12/31/2014  1/5/2015  Standard Class
# 51287   MX-2014-110527  12/31/2014  1/2/2015    Second Class
# 51288   MX-2014-114783  12/31/2014  1/6/2015  Standard Class
# 51289   CA-2014-156720  12/31/2014  1/4/2015  Standard Class
#
#           customer_name      segment             state        country  market  \
# 0       Toby Braunhardt     Consumer       Constantine        Algeria  Africa
# 1           Joseph Holt     Consumer   New South Wales      Australia    APAC
# 2         Annie Thurman     Consumer          Budapest        Hungary    EMEA
# 3          Eugene Moren  Home Office         Stockholm         Sweden      EU
# 4           Joseph Holt     Consumer   New South Wales      Australia    APAC
# ...                 ...          ...               ...            ...     ...
# 51285        Erica Bern    Corporate        California  United States      US
# 51286         Liz Preis     Consumer  Souss-Massa-Dra        Morocco  Africa
# 51287  Charlotte Melton     Consumer           Managua      Nicaragua   LATAM
# 51288     Tamara Dahlen     Consumer         Chihuahua         Mexico   LATAM
# 51289     Jill Matthias     Consumer          Colorado  United States      US
#
#         region  ...                                     product_name sales  \
# 0       Africa  ...                              Tenex Lockers, Blue   408
# 1      Oceania  ...                         Acme Trimmer, High Speed   120
# 2         EMEA  ...                          Tenex Box, Single Width    66
# 3        North  ...                      Enermax Note Cards, Premium    45
# 4      Oceania  ...                       Eldon Light Bulb, Duo Pack   114
# ...        ...  ...                                              ...   ...
# 51285     West  ...  Cardinal Slant-D Ring Binder, Heavy Gauge Vinyl    14
# 51286   Africa  ...          Wilson Jones Hole Reinforcements, Clear     4
# 51287  Central  ...           Hon Color Coded Labels, 5000 Label Set    26
# 51288    North  ...           Hon Legal Exhibit Labels, Alphabetical     7
# 51289     West  ...                              Bagged Rubber Bands     3
#
#       quantity discount    profit  shipping_cost  order_priority  year  \
# 0            2      0.0  106.1400          35.46          Medium  2011
# 1            3      0.1   36.0360           9.72          Medium  2011
# 2            4      0.0   29.6400           8.17            High  2011
# 3            3      0.5  -26.0550           4.82            High  2011
# 4            5      0.1   37.7700           4.70          Medium  2011
# ...        ...      ...       ...            ...             ...   ...
# 51285        2      0.2    4.5188           0.89          Medium  2014
# 51286        1      0.0    0.4200           0.49          Medium  2014
# 51287        3      0.0   12.3600           0.35          Medium  2014
# 51288        1      0.0    0.5600           0.20          Medium  2014
# 51289        3      0.2   -0.6048           0.17          Medium  2014
#
#        profit_flag customer_name_len
# 0         positive                15
# 1         positive                11
# 2         positive                13
# 3         negative                12
# 4         positive                11
# ...            ...               ...
# 51285     positive                10
# 51286     positive                 9
# 51287     positive                16
# 51288     positive                13
# 51289     negative                13
#
# [51290 rows x 23 columns]

# %% [markdown]
# # based on the quantity column, we will create a new column quantity_flag. If quantity is between 1 to 10,  quantity_flag will be low, 10-20, quantity_flag will be medium, 20-30 quantity_flag will be high

# %%
def quantity_flag(quantity):
    if quantity<10 and quantity>=1:
        return "low"
    if quantity<=20 and quantity>=10:
        return "med"
    if quantity<=30 and quantity>20:
        return "high"

# %%
sales_df['quantity_flag'] = sales_df['quantity'].apply(quantity_flag)

# %%
sales_df
# Out:
#               order_id  order_date ship_date       ship_mode  \
# 0         AG-2011-2040    1/1/2011  1/6/2011  Standard Class
# 1        IN-2011-47883    1/1/2011  1/8/2011  Standard Class
# 2         HU-2011-1220    1/1/2011  1/5/2011    Second Class
# 3      IT-2011-3647632    1/1/2011  1/5/2011    Second Class
# 4        IN-2011-47883    1/1/2011  1/8/2011  Standard Class
# ...                ...         ...       ...             ...
# 51285   CA-2014-115427  12/31/2014  1/4/2015  Standard Class
# 51286     MO-2014-2560  12/31/2014  1/5/2015  Standard Class
# 51287   MX-2014-110527  12/31/2014  1/2/2015    Second Class
# 51288   MX-2014-114783  12/31/2014  1/6/2015  Standard Class
# 51289   CA-2014-156720  12/31/2014  1/4/2015  Standard Class
#
#           customer_name      segment             state        country  market  \
# 0       Toby Braunhardt     Consumer       Constantine        Algeria  Africa
# 1           Joseph Holt     Consumer   New South Wales      Australia    APAC
# 2         Annie Thurman     Consumer          Budapest        Hungary    EMEA
# 3          Eugene Moren  Home Office         Stockholm         Sweden      EU
# 4           Joseph Holt     Consumer   New South Wales      Australia    APAC
# ...                 ...          ...               ...            ...     ...
# 51285        Erica Bern    Corporate        California  United States      US
# 51286         Liz Preis     Consumer  Souss-Massa-Dra        Morocco  Africa
# 51287  Charlotte Melton     Consumer           Managua      Nicaragua   LATAM
# 51288     Tamara Dahlen     Consumer         Chihuahua         Mexico   LATAM
# 51289     Jill Matthias     Consumer          Colorado  United States      US
#
#         region  ... sales quantity discount    profit shipping_cost  \
# 0       Africa  ...   408        2      0.0  106.1400         35.46
# 1      Oceania  ...   120        3      0.1   36.0360          9.72
# 2         EMEA  ...    66        4      0.0   29.6400          8.17
# 3        North  ...    45        3      0.5  -26.0550          4.82
# 4      Oceania  ...   114        5      0.1   37.7700          4.70
# ...        ...  ...   ...      ...      ...       ...           ...
# 51285     West  ...    14        2      0.2    4.5188          0.89
# 51286   Africa  ...     4        1      0.0    0.4200          0.49
# 51287  Central  ...    26        3      0.0   12.3600          0.35
# 51288    North  ...     7        1      0.0    0.5600          0.20
# 51289     West  ...     3        3      0.2   -0.6048          0.17
#
#        order_priority  year  profit_flag  customer_name_len quantity_flag
# 0              Medium  2011     positive                 15           low
# 1              Medium  2011     positive                 11           low
# 2                High  2011     positive                 13           low
# 3                High  2011     negative                 12           low
# 4              Medium  2011     positive                 11           low
# ...               ...   ...          ...                ...           ...
# 51285          Medium  2014     positive                 10           low
# 51286          Medium  2014     positive                  9           low
# 51287          Medium  2014     positive                 16           low
# 51288          Medium  2014     positive                 13           low
# 51289          Medium  2014     negative                 13           low
#
# [51290 rows x 24 columns]

# %%
list_index = sales_df[sales_df['quantity']==max(sales_df['quantity'])].index

# %%
sales_df.iloc[list_index]
# Out:
#              order_id  order_date   ship_date       ship_mode  \
# 230      ZA-2011-9910   1/19/2011   1/21/2011     First Class
# 313     IN-2011-85459   1/24/2011   1/30/2011  Standard Class
# 623      SF-2011-6380   2/15/2011   2/16/2011     First Class
# 685    CA-2011-154165   2/18/2011   2/25/2011  Standard Class
# 997    CA-2011-158337   3/11/2011   3/14/2011    Second Class
# ...               ...         ...         ...             ...
# 50174  CA-2014-169859  12/15/2014  12/19/2014  Standard Class
# 50297    AU-2014-3670  12/17/2014  12/22/2014  Standard Class
# 50382    TU-2014-9100  12/18/2014  12/22/2014  Standard Class
# 50880   ID-2014-85487  12/26/2014  12/30/2014  Standard Class
# 51161   ID-2014-52902  12/30/2014    1/1/2015     First Class
#
#            customer_name      segment             state        country  \
# 230      Patrick Gardner     Consumer           Eastern         Zambia
# 313        Jill Matthias     Consumer        Wellington    New Zealand
# 623       Pete Armstrong  Home Office           Gauteng   South Africa
# 685    Delfina Latchford     Consumer          Illinois  United States
# 997       Kelly Andreada     Consumer          New York  United States
# ...                  ...          ...               ...            ...
# 50174     Mike Pelletier  Home Office        California  United States
# 50297      Dianna Arnett  Home Office     Upper Austria        Austria
# 50382      Helen Abelman     Consumer          Istanbul         Turkey
# 50880      Darrin Martin     Consumer        Queensland      Australia
# 51161         Julia West     Consumer  Ho Ch¡ Minh City        Vietnam
#
#        market          region  ...  sales quantity discount    profit  \
# 230    Africa          Africa  ...    418       14     0.00   95.7600
# 313      APAC         Oceania  ...    420       14     0.00  147.0000
# 623    Africa          Africa  ...  2,785       14     0.00  779.5200
# 685        US         Central  ...     54       14     0.20    8.8088
# 997        US            East  ...    109       14     0.00   49.0140
# ...       ...             ...  ...    ...      ...      ...       ...
# 50174      US            West  ...     65       14     0.20   22.7360
# 50297    EMEA            EMEA  ...    720       14     0.00   64.6800
# 50382    EMEA            EMEA  ...    236       14     0.60  -58.8840
# 50880    APAC         Oceania  ...    244       14     0.40  -89.3760
# 51161    APAC  Southeast Asia  ...    327       14     0.47  -92.9754
#
#       shipping_cost  order_priority  year  profit_flag  customer_name_len  \
# 230          143.67        Critical  2011     positive                 15
# 313           20.03          Medium  2011     positive                 13
# 623          422.25        Critical  2011     positive                 14
# 685            4.11             Low  2011     positive                 17
# 997           12.24            High  2011     positive                 14
# ...             ...             ...   ...          ...                ...
# 50174          5.32            High  2014     positive                 14
# 50297         15.41          Medium  2014     positive                 13
# 50382          7.34          Medium  2014     negative                 13
# 50880         29.45            High  2014     negative                 13
# 51161         44.80            High  2014     negative                 10
#
#       quantity_flag
# 230             med
# 313             med
# 623             med
# 685             med
# 997             med
# ...             ...
# 50174           med
# 50297           med
# 50382           med
# 50880           med
# 51161           med
#
# [186 rows x 24 columns]
